# %%
import os
os.environ["DJANGO_SETTINGS_MODULE"] = "myhomework13.settings"
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

# %%
from mall.models import Shop

# %%
Shop.objects.all()
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" LIMIT 21; args=()
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Python310\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#
# C:\Python310\lib\site-packages\django\db\backends\sqlite3\base.py in execute(self, query, params)
#     422         query = self.convert_query(query)
# --> 423         return Database.Cursor.execute(self, query, params)
#     424
#
# OperationalError: no such table: mall_shop
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
Shop
# Out:
# mall.models.Shop

# %% [markdown]
# # Create

# %%
shop = Shop() # FirstShop (o). first_shop(x). firstShop(x). first_Shop(x)
shop.name = "투썸플레이스"
shop.telephone = " 042-1234-1234"

# %%
shop.save()
# Out:
# (0.000) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('투썸플레이스', '', ' 042-1234-1234', '', '2021-12-01 11:23:09.178189', '2021-12-01 11:23:09.178189'); args=['투썸플레이스', '', ' 042-1234-1234', '', '2021-12-01 11:23:09.178189', '2021-12-01 11:23:09.178189']
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Python310\lib\site-packages\django\db\backends\utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83             else:
# ---> 84                 return self.cursor.execute(sql, params)
#      85
#
# C:\Python310\lib\site-packages\django\db\backends\sqlite3\base.py in execute(self, query, params)
#     422         query = self.convert_query(query)
# --> 423         return Database.Cursor.execute(self, query, params)
#     424
#
# OperationalError: no such table: mall_shop
#
# ...
